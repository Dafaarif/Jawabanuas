# %%
import pandas as pd
import numpy as np
from math import cos,sin,pi
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('kebutuhan_per_bulan_2.csv')
df.head()
# Out:
#          Propinsi  tahun kebutuhan
# 0            ACEH   2005    619876
# 1  SUMATERA UTARA   2005    547255
# 2  SUMATERA BARAT   2005    501315
# 3            RIAU   2005    551498
# 4           JAMBI   2005    495242

# %%
df.shape
# Out:
# (374, 3)

# %%
df.columns
# Out:
# Index(['Propinsi', 'tahun', 'kebutuhan'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Propinsi'] = lb.fit_transform(df['Propinsi'])
df
# Out:
#      Propinsi  tahun kebutuhan
# 0           0   2005    619876
# 1          33   2005    547255
# 2          31   2005    501315
# 3          25   2005    551498
# 4           7   2005    495242
# ..        ...    ...       ...
# 369        26   2015   1981507
# 370        19   2015   2197450
# 371        20   2015   2333166
# 372        24   2015   2255113
# 373        23   2015   2171944
#
# [374 rows x 3 columns]

# %%
df.describe().T
# Out:
#           count    mean       std     min     25%     50%     75%     max
# Propinsi  374.0    16.5  9.823851     0.0     8.0    16.5    25.0    33.0
# tahun     374.0  2010.0  3.166514  2005.0  2007.0  2010.0  2013.0  2015.0

# %%
x=df.iloc[:,1:2].values # = x
y=df.iloc[:,0].values # = y

# %%
sns.pairplot(df,vars=['Propinsi', 'tahun', 'kebutuhan'])
plt.ioff()
